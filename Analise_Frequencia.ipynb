# %% [markdown]
# <a href="https://colab.research.google.com/github/arqPy/CAD/blob/main/Analise_Frequencia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Análise no Domínio da Frequência**
# ### **Plota Função Periódica**
#
# ---
#
# Code 01
# ---
#
# > **Important**
# >
# > - a
# > - b

# %%
import numpy as np

import matplotlib.pyplot as plt

t = np.arange(0, 50e-3, 1e-5)
f0 = 60

plt.figure(figsize=(10,6))
y = np.zeros(t.shape)

for n in range(1,50, 2):
  x = 4./np.pi*1./n*np.sin(2*np.pi*n*f0*t)
  y = y + x
  plt.plot(t, x)

plt.plot(t, y)
#plt.title("Fundamental")
#plt.xlabel("frequencia em Hertz")


#plt.figure(figsize=(10,6))
#plt.title("3a Harmonica")
#plt.xlabel("frequencia em Hertz")
#plt.plot(t, 4./np.pi*x3)

#plt.figure(figsize=(10,6))
#plt.title("Soma")
plt.xlabel("frequencia em Hertz")
#plt.plot(t, 4./np.pi*x)
# Out:
# Text(0.5, 0, 'frequencia em Hertz')

# %%
import numpy as np

import matplotlib.pyplot as plt

t = np.arange(0, 0.1, 1./1000)
f1, f2 = 16, 58

x1 = 3 * np.cos(2*np.pi*f1*t)

x2 = np.cos(2*np.pi*f2*t - np.pi/4)

x = x1 + x2

plt.figure(figsize=(10,6))

plt.title("Sinal de 16 Hz")
plt.ylim(-4,4)
plt.xlabel("frequencia em Hertz")

plt.plot(t, x1)

plt.figure(figsize=(10,6))

plt.title("Sinal de 58 Hz")
plt.ylim(-4,4)
plt.plot(t, x2)

plt.figure(figsize=(10,6))
plt.ylim(-4,4)
plt.plot(t, x)

plt.title("Sinal Combinado")

# Filtro

fc = 50
f = np.arange(1, 100, 1)

Hf = 1./(1 + (fc/f)**2)
Hf = np.sqrt(Hf)

plt.figure()
plt.grid(True)
plt.plot(f, Hf)

Hf_db = 20*np.log(Hf)

plt.figure()
plt.grid(True)
plt.plot(f, Hf_db)

# %%
# filtro passa faixa

import numpy as np

import matplotlib.pyplot as plt

# Dados
L = 0.1
C = 10e-6
R = 10
# Espectro

wR = 1./np.sqrt(L*C)
w = np.arange(1, 2*wR, wR/100)

Hw =  (1 - (w/wR)**2)/(w*R*C)
Hw = Hw*Hw
Hw = 1. + Hw
Hw = 1./np.sqrt(Hw)

plt.figure()
plt.grid(True)
plt.plot(w, Hw)

Hw = 20*np.log(Hw)
plt.figure()
plt.grid(True)
plt.plot(w, Hw)

# %%
"""
    Code 01

    periodic waves

"""

import numpy as np

import matplotlib.pyplot as plt

t = np.arange(0, 1, 1/1000)

x1 = 3 * np.cos(2*np.pi*6*t)

x2 = np.cos(2*np.pi*8*t - np.pi/4)

x = x1 + x2

plt.subplot(3, 1, 1)

plt.title("6 Hz signal")

plt.plot(t, x1)

plt.subplot(3, 1, 2)

plt.title("8 Hz signal")

plt.plot(t, x2)

plt.subplot(3, 1, 3)

plt.plot(t, x)

plt.title("Combined signal")

plt.tight_layout()

# Espectro

N = 16
fs = 32

dft = np.fft.fft(x[0:N])

plt.figure()
plt.title("DFT results")
n = np.arange(0, N)* fs/N
plt.stem( n, abs(dft[0:N]), use_line_collection=True )
plt.title("N = %d" % N)


plt.show()
# Out:
# <ipython-input-1-6fb7c5c2b3db>:50: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem( n, abs(dft[0:N]), use_line_collection=True )

# %% [markdown]
# <div class="warning" style='padding:0.1em; background-color:#E9D8FD; color:#69337A'>
# <span>
# <p style='margin-top:1em; text-align:center'>
# <b>Frequency- Domain Analysis</b></p>
# <p style='margin-bottom:1em; margin-right:1em; text-align:right; font-family:Georgia'> <b>- PlotPeriodic</b> <i>(Python Code)</i>
# </p></span><br><br>
#
# </p>
# <p style='margin-bottom:1em; margin-right:1em; text-align:right; font-family:Georgia'> <b>- PlotPeriodic2</b> <i>(Python Code)</i>
# </p></span>
# </p></span><br><br>
# Code running next
# </p>
# <p style='margin-bottom:1em; margin-right:1em; text-align:right; font-family:Georgia'> <b>- PlotSquare</b> <i>(Python Code)</i>
# </p></span>
# </p></span><br><br>
# """
#     examples of periodic signals, p 64, McClellan
# """
#
# import numpy as np
# import matplotlib.pyplot as plt
# t = np.arange(0, 0.1, 1/1000)
# f = 25
#
# # square wave
# k = 1
# x1 = 4/(k*np.pi)*np.cos(2*np.pi*k*f*t - np.pi/2)
# k = 3
# x3 = 4/(k*np.pi)*np.cos(2*np.pi*k*f*t - np.pi/2)
# k = 5
# x5 = 4/(k*np.pi)*np.cos(2*np.pi*k*f*t - np.pi/2)
# k = 7
# x7 = 4/(k*np.pi)*np.cos(2*np.pi*k*f*t - np.pi/2)
#
# #plt.subplot(4, 1, 1)
# plt.figure()
# plt.title("uses 1 harmonic")
# plt.plot(t, x1)
#
# #plt.subplot(4, 1, 2)
# plt.figure()
# plt.title("uses 2 harmonics")
# plt.plot(t, x1+x3)
#
# #plt.subplot(4, 1, 3)
# plt.figure()
# plt.title("uses 3 harmonics")
# plt.plot(t, x1+x3+x5)
#
# #plt.subplot(4, 1, 4)
# plt.figure()
# plt.title("uses 4 harmonics")
# plt.plot(t, x1+x3+x5+x7)
#
# #plt.tight_layout()
# plt.show()
#
#
# # use 25 harmonics
# y = np.zeros(t.shape)
#
# k = 1
# while k < 51:
#     x = 4/(k*np.pi)*np.cos(2*np.pi*k*f*t - np.pi/2)
#     y = y + x
#     k += 2
#
# plt.figure(2)
# # note that the little bump at the top of the square before the line
# #   drops is called the Gibbs phenomenon
# plt.title("uses first 25 harmonics")
# plt.plot(t, y)
#
# plt.tight_layout()
# plt.show()
# </p>
# <p style='margin-bottom:1em; margin-right:1em; text-align:right; font-family:Georgia'> <b>- PlotTriangle</b> <i>(Python Code)</i>
# </p></span>
# </p></span><br><br>
# """
#     examples of periodic signals, p 64, McClellan
# """
#
# import numpy as np
# import matplotlib.pyplot as plt
#
# t = np.arange(0, 0.1, 1/1000)
# f = 25
#
# # triangle wave
# k = 1
# x1 = -8/(k*k*np.pi*np.pi)*np.cos(2*np.pi*k*f*t)
# k = 3
# x3 = -8/(k*k*np.pi*np.pi)*np.cos(2*np.pi*k*f*t)
# k = 5
# x5 = -8/(k*k*np.pi*np.pi)*np.cos(2*np.pi*k*f*t)
# k = 7
# x7 = -8/(k*k*np.pi*np.pi)*np.cos(2*np.pi*k*f*t)
#
# #plt.subplot(4, 1, 1)
# plt.figure()
# plt.title("uses 1 harmonic")
# plt.plot(t, x1)
#
# #plt.subplot(4, 1, 2)
# plt.figure()
# plt.title("uses 2 harmonics")
# plt.plot(t, x1+x3)
#
# #plt.subplot(4, 1, 3)
# plt.figure()
# plt.title("uses 3 harmonics")
# plt.plot(t, x1+x3+x5)
#
# #plt.subplot(4, 1, 4)
# plt.figure()
# plt.plot(t, x1+x3+x5+x7)
# plt.title("uses 4 harmonics")
#
# #plt.tight_layout()
# plt.show()
#
# y = np.zeros(t.shape)
#
# k = 1
# while k < 51 :
#     x = -8/(k*k*np.pi*np.pi)*np.cos(2*np.pi*k*f*t)
#     y = y + x
#     k += 2
#
# plt.figure(2)
# plt.plot(t, y)
# plt.title("uses first 25 harmonics")
#
# plt.show()
# </p>
# </div>

# %%
"""
    periodic waves

    Tue Feb 13 23:11:24 CST 2018
"""

import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0, 2, 1/1000)

x1 = np.cos(2*np.pi*4.5*t)
x2 = np.cos(2*np.pi*7.5*t)

x = x1 + x2

plt.subplot(3, 1, 1)
plt.title("4.5 Hz signal")
plt.plot(t, x1)

plt.subplot(3, 1, 2)
plt.title("7.5 Hz signal")
plt.plot(t, x2)

plt.subplot(3, 1, 3)
plt.plot(t, x)
plt.title("Combined signal")
plt.xlabel("2 seconds of signal")


plt.tight_layout()
plt.show()

# %%
"""
    produce DFT of signal
"""

import numpy as np
import matplotlib.pyplot as plt

fs = 1024
t = np.arange(0, 1, 1/fs)
N = 512

f1 = 20
f2 = 100
y1 = 5 * np.cos(2*np.pi*f1*t)
y2 = np.cos(2*np.pi*f2*t)
y =  y1 + y2

plt.title("fs = %d, N = %d" % (fs, N))
plt.plot(t, y)

dft = np.fft.fft(y[0:N])
f0 = fs/N
plt.figure()
plt.title("DFT results")
f = np.arange(0, fs, f0)#np.arange(0, N)* fs/N
k = np.arange(0, N)
#plt.stem( f, abs(dft[0:N]), use_line_collection=True )
plt.stem( k, abs(dft[0:N]), use_line_collection=True )
plt.title("N = %d" % N)

#  zoom in
fd = int((fs-f1)//f0 + 5)

plt.figure()
plt.title("zoom in around " + str(fs - f1) + " Hz")
plt.stem( f[fd-100:fd], abs(dft[fd - 100:fd]), use_line_collection=True )

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-14-af8d28713914>:28: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem( k, abs(dft[0:N]), use_line_collection=True )
# <ipython-input-14-af8d28713914>:36: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem( f[fd-100:fd], abs(dft[fd - 100:fd]), use_line_collection=True )

# %%
20//3 + 5
# Out:
# 11

# %%
"""
    Sat Feb 24 14:56:05 CST 2018

    produce DFT of signal; demonstrates spectral leakage
"""

import numpy as np
import matplotlib.pyplot as plt
from scipy import signal


fs = 1024
t = np.arange(0, 1, 1/fs)

f1 = 20
f2 = 100
y1 = np.cos(2*np.pi*f1*t)
y2 = np.cos(2*np.pi*f2*t)
y =  y1 + y2

N = 500
f0 = fs/N

yPart = y[0:N]

plt.title("fs = %d, N = %d" % (fs, N))
plt.plot(t, y)

dft = np.fft.fft(yPart)

plt.figure()
plt.title("DFT results, f0 = %.3f" % f0)
n = np.arange(0, N)* f0
plt.stem( n, abs(dft), use_line_collection = True )

#  zoom in
plt.figure()
plt.title("zoom in around 20Hz")
plt.stem( n[0:15], abs(dft[0:15]), use_line_collection = True )

##############
#  apply Hamming window
hamming = signal.hamming(len(yPart))
newY = hamming*yPart
plt.figure()
plt.plot(t[0:N], newY)
plt.title("windowed signal")

plt.figure()
dft2 = np.fft.fft(newY)
plt.title("after applying Hamming window")
plt.stem( n, abs(dft2), use_line_collection = True )

#  zoom in
plt.figure()
plt.title("zoom in around 20Hz")
plt.stem( n[0:15], abs(dft2[0:15]), use_line_collection = True )

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-5-5afa973539d4>:34: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem( n, abs(dft), use_line_collection = True )
# <ipython-input-5-5afa973539d4>:39: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem( n[0:15], abs(dft[0:15]), use_line_collection = True )
# <ipython-input-5-5afa973539d4>:43: DeprecationWarning: Importing hamming from 'scipy.signal' is deprecated and will raise an error in SciPy 1.13.0. Please use 'scipy.signal.windows.hamming' or the convenience function 'scipy.signal.get_window' instead.
# ...

# %%
"""
    what do the poles and zeros do?
    my own example based on the example from pp 112-114
      of Intro to DSP by Lynn & Fuerst
"""

import numpy as np
import matplotlib.pyplot as plt
from scipy import signal


def myFilter(x, N) :
    # y[n] =  -0.81y[n-2] + 0.1x[n] - 0.1x[n-2]
    y = np.zeros(N)

    y[0] = 0 + 0.1*x[0] - 0  # y[-2] = x[-2] = 0
    y[1] = 0 + 0.1*x[1] - 0  # y[-1] = x[-1] = 0

    n = 2
    while n < fs :
        y[n] = -0.81*y[n-2] + 0.1*x[n] - 0.1*x[n-2]
        n += 1

    return y

def findY(x, N, title, printRange) :
    y = myFilter(x, N)

    plt.figure()
    plt.plot(y[0:printRange])
    plt.title("output of filter, input = %s" % title)
    plt.show()

###########  main  ###########
fs = 1000
t = np.arange(0, 1, 1/fs)
N = t.size


# H(z) = B(z)/A(z)
b = np.array([1, 0, -1])
a = np.array([1, 0,  0.81])

plt.figure()
#                   X, Y
x, y = signal.freqz(b, a)
n = fs*x/(2*np.pi)
plt.plot(n, abs(y))
plt.title("Original Frequency Response")
plt.xlabel("Frequency (Hz)")
plt.show()

b = np.array([0.1, 0, -0.1])
a = np.array([1, 0,  0.81])

plt.figure()
#                   X, Y
x, y = signal.freqz(b, a)
n = fs*x/(2*np.pi)
plt.plot(n, abs(y))
plt.title("Original Frequency Response")
plt.xlabel("Frequency (Hz)")
plt.show()


f1 = 7
x1 = np.cos(2 * np.pi * f1 * t)

printRange = 1000
plt.figure()
plt.plot(x1[0:printRange])
plt.title("input: x1 = %d Hz" % f1)
plt.show()

findY(x1, N, "%d Hz" % (f1), printRange)

printRange = 200
f2 = 250
x2 = np.cos(2 * np.pi * f2 * t)
plt.figure()
plt.plot(x2[0:printRange])
plt.xlim([0, printRange])
plt.title("input: x2 = %d Hz" % f2)
plt.show()

findY(x2, N, "%d Hz" % (f2), printRange)

# %%
import numpy as np
x = [2, 2, 2, 2]
N = 4
w0 = 2*np.pi/N
W_N = -1j*w0
W_N = np.exp(W_N)
print(W_N)
X = np.zeros(N)
for k in range(N):
  for n in range(N):
    X[k] = X[k] + x[n]*(W_N**(k*n))
  if abs(X[k]) < 1e-10:
    X[k] = 0


print(X)
# Out:
# (6.123233995736766e-17-1j)
# [8. 0. 0. 0.]
# <ipython-input-2-4061a8019a09>:11: ComplexWarning: Casting complex values to real discards the imaginary part
#   X[k] = X[k] + x[n]*(W_N**(k*n))

# %%
print("W_N = ", W_N)
for m in range(4):
  z = W_N**m
  zr =  z.real
  zi =  z.imag
  if abs( zr) < 1e-10:
    zr = 0
  if abs( zi) < 1e-10:
    zi = 0
  z = zr + 1j*zi
  print(m, z)
# Out:
# W_N =  (6.123233995736766e-17-1j)
# 0 (1+0j)
# 1 -1j
# 2 (-1+0j)
# 3 1j

# %%
fa= 1000
N = 16
f0 = fa/16
f = [k*f0 for k in range(N) ]
print(f)
# Out:
# [0.0, 62.5, 125.0, 187.5, 250.0, 312.5, 375.0, 437.5, 500.0, 562.5, 625.0, 687.5, 750.0, 812.5, 875.0, 937.5]

# %%
# testando código de aluno
import numpy as np
w0 = 2*np.pi/N
for k in range(4):
  z1 = np.exp(w0*(-1j*k))
  z2 = np.exp(w0*(-2j*k))
  z3 = np.exp(w0*(-3j*k))
  X = 1 - z1 + z2 - z3
  print(k, X)
# Out:
# 0 0j
# 1 (7.267471740958731e-17-1.1102230246251565e-16j)
# 2 (4+7.347880794884119e-16j)
# 3 (-3.2904645469127765e-16-4.440892098500626e-16j)

# %%
import numpy as np
x = [2, 2, 2, 2]
N = 4
w0 = 2*np.pi/N
W_N = -1j*w0
W_N = np.exp(W_N)
X =[]
for k in range(N):
  e = 0
  for n in range(N):
    e = e + x[n]*(W_N**(k*n))
  X.append(e)
X
# Out:
# [(8+0j),
#  (-3.6739403974420594e-16-4.440892098500626e-16j),
#  -4.898587196589412e-16j,
#  (6.580929093825553e-16-6.661338147750939e-16j)]

# %%
import numpy as np
fci = 8750
fcs = 11250
BW = fcs - fci
f0 = (fcs*fci)**0.5
Q0 = f0/BW

k = 2 # valor adotado (k < 2Q0^2)

C = 10/f0*1e-6

C = 1e-9 # valor adotado

w0 = 2*3.14*f0
print("BW =%.2e , w0 =%.2f , f0 =%.2f , Q0 =%.2f " %(BW, w0, f0, Q0))
R1 = Q0/(w0*C*k)
R2 = Q0/(w0*C*(2*Q0**2 - k))
R3 = 2*Q0/(w0*C)

print("C =%.2e , R1 =%.2f , R2 =%.2f , R3 =%.2f " %(C, R1, R2, R3))
# Out:
# BW =2.50e+03 , w0 =62307.44 , f0 =9921.57 , Q0 =3.97
# C =1.00e-09 , R1 =31847.13 , R2 =2159.13 , R3 =127388.54

# %%
Q0
# Out:
# 2.449489742783178

# %%
"""
    https://youtu.be/I9Skfd-VOwA?si=oa9Hh5Luwc0SZAep
"""

import numpy as np
import matplotlib.pyplot as plt
from scipy import signal


fs = 1000
N = 500

t = np.arange(0, N )/fs

f1 = 31

x = 2*np.cos(2*np.pi*f1*t)


df = fs/N


plt.title("fs = %d, N = %d" % (fs, N))
plt.plot(t, x)

y = np.fft.fft(x)
y_amp = abs(y)

plt.figure()
plt.title("DFT results, $\Delta f $= %.2f" % df)
n = np.arange(0, N)* df
plt.stem( n, y_amp[0:N+1], use_line_collection = True )

#  zoom in
plt.figure()
plt.title("zoom in around 31Hz")
plt.stem( n[0:30], y_amp[0:30], use_line_collection = True )


plt.tight_layout()
plt.show()
# Out:
# <ipython-input-17-c6bd32865ab2>:32: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem( n, y_amp[0:N+1], use_line_collection = True )
# <ipython-input-17-c6bd32865ab2>:37: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem( n[0:30], y_amp[0:30], use_line_collection = True )

# %%
fs = 500
N = 500
df = fs/N

t = np.arange(0, N )/fs

f1 = 31

x = 2*np.cos(2*np.pi*f1*t)


df = fs/N


plt.title("fs = %d, N = %d" % (fs, N))
plt.plot(t, x)

y = np.fft.fft(x)
y_amp = abs(y)

plt.figure()
plt.title("DFT results, $\Delta f $= %.2f" % df)
n = np.arange(0, N)* df
plt.stem( n, y_amp[0:N], use_line_collection = True )

#  zoom in
plt.figure()
plt.title("zoom in around 31Hz")
plt.stem( n[0:40], y_amp[0:40], use_line_collection = True )


plt.tight_layout()
plt.show()
# Out:
# <ipython-input-18-13a1298b3945>:24: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem( n, y_amp[0:N], use_line_collection = True )
# <ipython-input-18-13a1298b3945>:29: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem( n[0:40], y_amp[0:40], use_line_collection = True )

# %%
len(n)
# Out:
# 500

# %% [markdown]
# # Filtros

# %%
"""
    generate FIR coefficients for ideal lowpass filter
"""

import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

def genFilter(fs, fc, taps) :
    w = 2*np.pi*fc/fs

    # centered at zero
    n = np.arange(-(taps-1)//2, (taps-1)//2 + 1, 1)
    h = np.zeros(taps)

    #  the impulse response will be symmetric, so only
    #  need to calculate first half
    print("filter coefficients, taps = %d" % taps)
    i = 0
    while i < taps//2 :
        h[i] = np.sin(n[i] * w)/(np.pi * n[i])
        end = taps - i - 1
        h[end] = h[i]
        print("h[%2d] = %9f, h[%2d] = %9f" % (i, h[i], end, h[end]))
        i += 1

    h[i] = w/np.pi
    print("h[%2d] = %9f\n" % (i, h[i]))

    plt.stem(h, use_line_collection=True)
    plt.title("filter coefficients, taps = %d" % taps)
    plt.show()

    return h

def plotFreqResponse(h, taps, fs) :
    freq, response = signal.freqz(h)
    #  https://stackoverflow.com/questions/29620694/matlab-freqz-function-in-python
    f = fs * freq / (2 * np.pi)

    plt.plot(f, np.abs(response))
    plt.title("frequency response, taps = %d" % taps)
    plt.grid()
    plt.show()

def applyWindows(h, taps, fs) :
    M = taps - 1

    # centered at zero
    n = np.arange(-M//2, M//2 + 1, 1)

    # von Hann
    w = 0.5 + 0.5*np.cos(2*np.pi*n/M)
    plt.plot(n, w)
    hann = h*w

    # Hamming
    w = 0.54 + 0.46*np.cos(2*np.pi*n/M)
    plt.plot(n, w, 'r')
    hamming = h*w
    plt.title("Windows, taps = %d" % taps)
    plt.legend(["von Hann", "Hamming"])
    plt.show()

    plt.stem(hamming, use_line_collection=True)
    plt.title("filter coefficients after Hamming, taps = %d" % taps)
    plt.show()

    #  plot frequency responses
    #  log scale
    freq, response = signal.freqz(hann)
    #  https://stackoverflow.com/questions/29620694/matlab-freqz-function-in-python
    f = fs * freq / (2 * np.pi)
    plt.plot(f, np.abs(response))

    freq, response = signal.freqz(hamming)
    plt.plot(f, np.abs(response))
    plt.title("frequency responses after apply window, taps = %d" % taps)
    plt.legend(["von Hann", "Hamming"])
    plt.grid()
    plt.show()

    #  plot frequency responses
    #  log scale
    freq, response = signal.freqz(hann)
    f = fs * freq / (2 * np.pi)
    #plt.plot(f, np.abs(response))
    plt.plot(f, 20 * np.log10(np.abs(response)) )

    freq, response = signal.freqz(hamming)
    f = fs * freq / (2 * np.pi)
    #plt.plot(f, np.abs(response))
    plt.plot(f, 20 * np.log10(np.abs(response)), 'r')

    plt.xlabel("Hertz")
    plt.ylabel("db")
    plt.title("frequency responses after apply window, taps = %d" % taps)
    plt.legend(["von Hann", "Hamming"])
    plt.grid()
    plt.show()



###################  main  ###################
#  trying to replicate values in example at
#    http://www.labbookpages.co.uk/audio/firWindowing.html
fs = 2000
fc = 460

taps = 11
h = genFilter(fs, fc, taps)
plotFreqResponse(h, taps, fs)

taps = 99
h = genFilter(fs, fc, taps)
plotFreqResponse(h, taps, fs)

##########################################
#  apply windows to filter coefficients
taps = 21

h = genFilter(fs, fc, taps)
plotFreqResponse(h, taps, fs)
applyWindows(h, taps, fs)
# Out:
# filter coefficients, taps = 11
# h[ 0] =  0.051504, h[10] =  0.051504
# h[ 1] = -0.038337, h[ 9] = -0.038337
# h[ 2] = -0.098652, h[ 8] = -0.098652
# h[ 3] =  0.039580, h[ 7] =  0.039580
# h[ 4] =  0.315800, h[ 6] =  0.315800
# h[ 5] =  0.460000
# <ipython-input-1-ff7d17020c37>:30: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(h, use_line_collection=True)
# filter coefficients, taps = 99
# h[ 0] =  0.006445, h[98] =  0.006445
# h[ 1] =  0.001649, h[97] =  0.001649
# h[ 2] = -0.006297, h[96] = -0.006297
# h[ 3] = -0.003334, h[95] = -0.003334
# h[ 4] =  0.005723, h[94] =  0.005723
# h[ 5] =  0.004952, h[93] =  0.004952
# h[ 6] = -0.004719, h[92] = -0.004719
# h[ 7] = -0.006399, h[91] = -0.006399
# h[ 8] =  0.003306, h[90] =  0.003306
# ...

# %%
"""
    produce DFT of signal TESTE
"""

import numpy as np
import matplotlib.pyplot as plt

w0 = 0.4*np.pi
f1 = 1.2
f2 = 1.6

fs = 4 # maior que 2*fmax
t = np.arange(0, 1, 1/fs)
N = 5

y1 = 4 * np.cos(2*np.pi*f1*t)
y2 = 2*np.sin(2*np.pi*f2*t)
y =  y1 + y2

plt.title("fs = %d, N = %d" % (fs, N))
plt.plot(t, y)

dft = np.fft.fft(y[0:N])

plt.figure()
plt.title("DFT results")
n = np.arange(0, N)* fs/N
plt.stem( n, abs(dft[0:N]), use_line_collection=True )
plt.title("N = %d" % N)


plt.tight_layout()
plt.show()
# Out:
# <ipython-input-1-1c4e3cd95422>:28: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem( n, abs(dft[0:N]), use_line_collection=True )
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-1c4e3cd95422> in <cell line: 28>()
#      26 plt.title("DFT results")
#      27 n = np.arange(0, N)* fs/N
# ---> 28 plt.stem( n, abs(dft[0:N]), use_line_collection=True )
#      29 plt.title("N = %d" % N)
#      30
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     408                          else deprecation_addendum,
#     409                 **kwargs)
# ...

# %%
"""
    https://youtu.be/I9Skfd-VOwA?si=oa9Hh5Luwc0SZAep
"""

import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

'''
fs = 96
N = 96
f1 = 12
f2 = 16
'''

fs = 4
N = 50
f1 = 1.2
f2 = 1.6

t = np.arange(0, N )/fs



x = 4*np.cos(2*np.pi*f1*t) + 2*np.sin(2*np.pi*f2*t)


df = fs/N


plt.title("fs = %d, N = %d" % (fs, N))
plt.plot(t, x)

y = np.fft.fft(x)
y_amp = abs(y)

plt.figure()
plt.title("DFT results, $\Delta f $= %.2f" % df)
n = np.arange(0, N)* df
plt.stem( n, y_amp[0:N+1], use_line_collection = True )

'''
#  zoom in
plt.figure()
plt.title("zoom in around 31Hz")
plt.stem( n[0:30], y_amp[0:30], use_line_collection = True )
'''

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-14-9d70898221fc>:40: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem( n, y_amp[0:N+1], use_line_collection = True )

# %%
import numpy as np
import matplotlib.pyplot as plt
N_0 = 32

x_n = [1]*5 + [0]*23 + [1]*4
x_n = np.array(x_n)

X_r = np.zeros(N_0)

w0 = 2*np.pi/N_0
W_N = -1j*w0
W_N = np.exp(W_N)

for k in range(N_0):
  for n in range(N_0):
    X_r[k] = X_r[k] + x_n[n]*(W_N**(k*n))/N_0

n = np.arange(0, N_0)

plt.figure()
plt.title("Sinal")
plt.stem( n, x_n, use_line_collection = True )

plt.figure()
plt.title("Cálculo Direto")
plt.stem( n, X_r, use_line_collection = True )

X_r = np.fft.fft(x_n)/N_0
plt.figure()
plt.title("Cálculo pela FFT")
plt.stem( n, X_r, use_line_collection = True )
# Out:
# <ipython-input-5-b5128a2ab4ab>:16: ComplexWarning: Casting complex values to real discards the imaginary part
#   X_r[k] = X_r[k] + x_n[n]*(W_N**(k*n))/N_0
# <ipython-input-5-b5128a2ab4ab>:22: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem( n, x_n, use_line_collection = True )
# <ipython-input-5-b5128a2ab4ab>:26: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem( n, X_r, use_line_collection = True )
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi

n = 2 ** 6 # Número de intervalos
f = 400.0 # Hz
dt = 1 / (f * 16) # Espaciado, 16 puntos por período
t = np.linspace(0, (n - 1) * dt, n) # Intervalo de tiempo en segundos
y = np.sin(2 * pi * f * t) - 0.5 * np.sin(2 * pi * 2 * f * t) # Señal
plt.plot(t, y)
plt.plot(t, y, 'ko')
plt.xlabel('Tiempo (s)')
plt.ylabel('$y(t)$')
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
N_0 = 16

x_n = [1]*4 + [0]*9 + [1]*3
x_n = np.array(x_n)

n = np.arange(0, N_0)


plt.figure()
plt.title("Sinal")
plt.stem( n, x_n, use_line_collection = True )



X_r = np.fft.fft(x_n)/N_0
plt.figure()
plt.title("Cálculo pela FFT")
plt.stem( n, X_r, use_line_collection = True )
# Out:
# <ipython-input-5-7fce485afdb5>:13: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem( n, x_n, use_line_collection = True )
# <ipython-input-5-7fce485afdb5>:20: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem( n, X_r, use_line_collection = True )
# <StemContainer object of 3 artists>

# %%
n
# Out:
# 64
